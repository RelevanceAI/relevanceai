# %%
# !pip install 'relevanceai[vis]'

# %%
'''
Available DR and Cluster configuration
'''
from typing import Union
from typing_extensions import Literal

# ==================================================
# =============== DR Args ==========================
# ==================================================

DIM_REDUCTION = Literal["pca", "tsne", "umap", "ivis"]
DIM_REDUCTION_DEFAULT_ARGS = {
    'pca': {
        "svd_solver": "auto",
        "random_state": 42
    },
    'tsne': {
        "init": "pca",
        "n_iter": 500,
        "learning_rate": 100,
        "perplexity": 30,
        "random_state": 42,
    },
    'umap': {
        "n_neighbors": 15,
        "min_dist": 0.1,
        "random_state": 42,
        "transform_seed": 42,
    },
    'ivis': {
        "k": 15, 
        "model": "maaten", 
        "n_epochs_without_progress": 2
    }
}


# ==================================================
# =============== Cluster Args =====================
# ==================================================

CLUSTER_NUMERIC = Literal["kmeans", "kmedoids",  None]
CLUSTER_CATEGORICAL = Literal["kmodes",  None]
CLUSTER_MIXED = Literal["kprotoypes", None]
CLUSTER = Union[CLUSTER_NUMERIC, CLUSTER_CATEGORICAL, CLUSTER_MIXED]

CLUSTER_DEFAULT_ARGS = {
    'kmeans': {
        "init": "k-means++", 
        "verbose": 1,
        "compute_labels": True,
        "max_no_improvement": 2
    },
    'kmedoids': {
        "metric": "euclidean",
        "init": "k-medoids++",
        "random_state": 42,
        "method": "pam"
    },
    
## Not yet fully implemented
#     'kmodes': {
#         "init": "Huang", 
#         "verbose": 1,
#         "random_state": 42,
#         "n_jobs": -1
#     },
#     'kprototypes': {
#         "init": "Huang", 
#         "verbose": 1,
#         "random_state": 42,
#         "n_jobs": -1
#     }
}

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from relevanceai.http_client import Client

dataset_id = "ecommerce-6"
project = "dummy-collections"
api_key = "UzdYRktIY0JxNmlvb1NpOFNsenU6VGdTU0s4UjhUR0NsaDdnQTVwUkpKZw"  # Read access
base_url = "https://api-aueast.relevance.ai/v1/"

client = Client(project=project, api_key=api_key, base_url=base_url)

'''
Retrieve docs in dataset  set `number_of_points_to_render = None` to retrieve all docs
If `vector_label` None, shows markers only and throws a warning
Default dim reduction is 'pca' with default args above
'''

vector_label = "product_name"
vector_field = "product_name_imagetext_vector_"

client.projector.plot(
    dataset_id=dataset_id, 
    vector_field=vector_field,
    number_of_points_to_render=1000
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2021-11-08 08:11:09.649 | SUCCESS  | relevanceai.http_client:__init__:43 - Welcome to the development version of the relevanceai Python SDK
# ../relevanceai/visualise/projection.py:260: UserWarning:
#
# The vector label has not been specified.
# 2021-11-08 08:11:20.266 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:11:40.455 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:11:51.549 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/schema)
# <div>                            <div id="a267dd4d-9bb1-4989-a46e-d036d9ca6370" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
972209800895312,-1.6595109471874043,-0.5057029701103073,0.002612885096263245,1.468339828360778,2.3394789525521458,1.6005461588591705,-1.0387097736230146,-0.46821680998756626,0.2748359988135075,1.47919062411186,0.01392145462273203,-0.5376193987487622,-0.4395081950966183,-0.6163045617427958,2.117600853192356,0.5394961282221042,0.5490671109962686,-0.29168959758487206,0.3667605737838423,-0.9203406044406387,1.885871210548631,-0.37503502948752393,-0.542006242340862,1.6703140406490975,1.9733743279531875,0.12402053214983934,1.5806941087753514,1.2957449427589456,-0.37508101944211536,1.5501524066752461,-1.6304197061199583,-0.5083892490224217,1.32873435891 ...

# %%
'''
If `vector_label` specified, will show `vector_label` as text
Char length can be varied via `vector_label_char_length`
`hover_label` allows you display extra dataset information on hover
'''

dr = 'umap'
cluster = 'kmedoids'

vector_label = "product_name"
vector_field = "product_name_imagetext_vector_"


client.projector.plot(
    ### DR Args for vector plot
    dataset_id = dataset_id,
    vector_field = vector_field,
    dr = dr,
    dr_args = DIM_REDUCTION_DEFAULT_ARGS[ dr ],
    number_of_points_to_render=1000,
    
    ## Plot rendering options
    vector_label = vector_label, 
    vector_label_char_length = 10,
    hover_label = [ vector_label, 'category' ]
)
# Out:
# 2021-11-08 08:28:08.881 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:28:29.866 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:28:38.795 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/schema)
# <div>                            <div id="6159528d-1a7c-4ada-b40b-5fce4ba1b988" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6159528d-1a7c-4ada-b40b-5fce4ba1b988")) {                    Plotly.newPlot(                        "6159528d-1a7c-4ada-b40b-5fce4ba1b988",                        [{"customdata":[["Miss Clyra Women's Brief Panty","Clothing "],["\u8f7b\u677e\u56ed\u827a\u5bb6\u5ead\u690d\u7269\u5bb9\u5668\u5957\u88c5","Tools & Hardware "],["Natures Plus Home Garden Plant Container Set","Tools & Hardware "],["\u52a0\u5c14\u5179 4 \u6c38\u8fdc\u4ee4\u4eba\u60ca\u53f9\u7684\u91d1\u4e54\u514b\u5408\u91d1\u4e54\u514b","Jewellery "],["\u665a\u5b89\u5929\u4f7f\u7761\u7720\u826f\u597d\u7684\u56fe\u7247\u7eb8\u6253\u5370","Home Decor & Festive Needs "],["\u5c3c\u4ec0\u5854\u9ec4\u91d1 22 K \u73af","Jewellery "],["\u767d\u683c\u59c6\u65af\u5438\u5f15\u8fbe\u59c6\u838e\u91d1\u94bb 18 K \u6212\u6307","Jewellery "],["\u8bbe\u8ba1\u74e6\u62c9\u65af\u8282\u65e5\u5305 \uff08\u5957 2\uff09 \u7b14\u8bb0\u672c\u786c\u7ed1\u5b9a","Pens & Stationery "],["IBS \u5851\u6599\u4fbf\u643a\u5f0f\u7b14\u8bb0\u672c\u7535\u8111\u684c","Furniture "],["Trinketbag Pearls & Seep Fabric, Metal Necklace","Jewellery "],["Hot Muggs LTS O3 Italy Steel Tumbler","Kitchen & Dining "],["\u9996\u9009\u68c9\u7ee3\u8fea\u4e07\u5957\u88c5","Home Furnishing "],["\u57c3\u65af\u8d1d\u8fbe\u80a9\u5305","Bags, Wallets & Belts "],["\u7a7f\u4f60\u7684\u5149\u7531 Pcj \u5929\u62c9\u91d1\u94bb 18 K \u6212\u6307","Jewellery "],["Speedwav 207232 Hood, Bumper Car Sticker","Automotive "],["\u7eb3\u4e9a\u8428\u97ad1200\u6beb\u5347\u74f6","Kitchen & Dining "],["\u6069\u675c\u62c9\u5854\u74e6\u76f4\u5f8428\u5398\u7c73","Kitchen & Dining "],["\u5bb6\u5ead\u65f6\u5c1a\u753b\u5eca\u805a\u916f\u9a6c\u9f99\uff0c\u68d5\u8272\u666e\u901a\u773c\u957f\u95e8\u7a97\u5e18","Home Furnishing "],["Radiant Bay Statusque Yellow Gold Diamond 18 K Ring","Jewellery "],["\u82f9\u679c ipad \u7a7a\u6c14 2 \u7684\u70c2\u80cc\u76d6","Mobiles & Accessories "],["killys Men's Solid No Show Socks","killys Men's Solid No Show Socks"],["\u5361\u52aa\u4e66\u5c01\u9762\u60e0\u666e\u77f3\u677f 7","Mobiles & Accessories "],["House Of Tantrums Women's Solid Casual Shirt","Clothing "],["\u722a\u5b50\u5706\u4e0d\u9508\u94a2\u5ba0\u7269\u7897","Pet Supplies "],["Karatcraft Tilany Gold Diamond 18 K Ring","Jewellery "],["AdroitZ Exclusive Barbie Doll Sunshade / curtain (set of 2) for Honda city type 3 Sun Shade For Honda City","Automotive "],["Cm Treder cm h4 light 145 Motorbike LED Bulb","Automotive "],["RAA \u7537\u58eb\u7b80\u62a5","Clothing "],["\u65af\u74e6\u52a0\u5987\u5973\u5835\u585e","Footwear "],["Parinaaz Alloy Mangalsutra","Jewellery "],["69th Avenue 69SS0002-X1 Polyester, Steel Sliding Pin Shirt Stud","Clothing "],["Fabpoppy Women's Printed Casual Shirt","Clothing "],["Voylla Artifictial Silver Plated Alloy Necklace","Jewellery "],["\u5361\u62c9\u7279\u514b\u62c9\u592b\u7279\u4f69\u59ae\u5957\u9ec4\u91d1\u94bb\u77f3 18 K \u73af","Jewellery "],["Rainfun RF1003 Umbrella","Toys & School Supplies "],["People Women's Checkered Casual Shirt","Clothing "],["\u513f\u7ae5\u6751\u5e94\u7528\u7a0b\u5e8f\u5706\u9888\u4f11\u95f2\u5973\u5b69\u7684\u6bdb\u8863","Clothing "],["Rakam Gold Emerald, Diamond 18 K Ring","Jewellery "],["Simrit Women's Nighty","Clothing "],["Allure Auto CM 1655 Car Mat Mitsubishi Cielo","Automotive "],["\u666e\u6d1b\u59c6\u5179 Pz-30b \u5973\u5b50 T\u6064\u80f8\u7f69","Clothing "],["\u82f9\u679c iPad \u8ff7\u4f60\u7684\u6bcf\u65e5\u5bf9\u8c61\u540e\u76d6\uff0c\u89c6\u7f51\u819c\u663e\u793a","Mobiles & Accessories "],["Enthopia Back Cover for iPad Mini, iPad Mini 2, iPad Mini Retina","Mobiles & Accessories "],["Mandhania Cotton Bath Towel","Home Furnishing "],["\u5 ...

# %%
'''
If `colour_label` specified, will render colour_label as legend
You can set `colour_label_char_length` to shorten displayed legend
'''

dr = 'umap'
cluster = 'kmedoids'

vector_label = "product_name"
vector_field = "product_name_imagetext_vector_"

client.projector.plot(
    dataset_id = dataset_id,
    vector_field = vector_field,
    number_of_points_to_render=100,
    
    ### Dimensionality reduction args
    dr = dr,
    dr_args = DIM_REDUCTION_DEFAULT_ARGS[ dr ],
    
    ## Plot rendering args
    vector_label = None, 
    colour_label = vector_label,
    colour_label_char_length = 20,
    hover_label = [ vector_label,  'category'],
)
# Out:
# 2021-11-08 09:14:35.390 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 09:14:38.469 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 09:14:39.381 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/schema)
# <div>                            <div id="ae648b6a-5406-4d3e-bdbc-8ae7781e4fcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae648b6a-5406-4d3e-bdbc-8ae7781e4fcc")) {                    Plotly.newPlot(                        "ae648b6a-5406-4d3e-bdbc-8ae7781e4fcc",                        [{"customdata":[["\u6770\u745e\u7684 Jppb11591 S \u5ba0\u7269\u5e8a","Furniture "],["\u57c3\u8482\u6728\u9879\u94fe","Jewellery "],["Silly People Women's Solid Casual Shirt","Clothing "],["\u4f0a\u677e\u662fV01","Computers "],["Karatcraft Crisanta Yellow Gold Diamond 18 K Ring","Jewellery "],["\u6c83\u4f0a\u62c9\u4eba\u5de5\u7ecf\u5178\u7eaf\u6c34\u6676\u9ec4\u91d1\u9540\u5408\u91d1\u9879\u94fe","Jewellery "],["Floozy Its My Choice Women's Push-up Bra","Clothing "],["\u8fc8\u6069\u7279\u56fa\u4f53\u5973\u5b50\u81ea\u884c\u8f66\u77ed\u88e4\uff0c\u5065\u8eab\u77ed\u88e4\uff0c\u6e38\u6cf3\u77ed\u88e4","Clothing "],["Harp Limone Metal Necklace","Jewellery "],["XEBAC XEBAC-CHARGER-B895 Battery Charger","Mobiles & Accessories "],["\u91ce\u9a6c\u8170\u888b","Sports & Fitness "],["U United Mad Angle DU 14 L Backpack","Bags, Wallets & Belts "],["Indian Charm Beads Bone, Stone Necklace","Jewellery "],["Allure Auto CM 367 Car Mat Maruti Ritz","Automotive "],["\u5ba0\u7269\u96e8\u8863\u72d7\uff0c\u732b","Pet Supplies "],["\u963f\u8fb
# %%
'''
If `cluster` specified, will override `colour_label` option and render cluster as legend
'''

dr = 'tsne'
cluster = 'kmedoids'

vector_label = "product_name"
vector_field = "product_name_imagetext_vector_"


client.projector.plot(
    dataset_id = dataset_id,
    vector_field = vector_field,
    number_of_points_to_render=100,
    
    ### Dimensionality reduction args
    dr = dr,
    dr_args = DIM_REDUCTION_DEFAULT_ARGS[ dr ], 

    ## Plot rendering args
    vector_label = None, 
    colour_label = vector_label,
    hover_label = [ vector_label, 'category' ],
    
    ### Cluster args
    cluster = cluster,
    cluster_args = {"n_clusters": 10, **CLUSTER_DEFAULT_ARGS[ cluster ]},
)
# Out:
# ../relevanceai/visualise/projection.py:260: UserWarning:
#
# The vector label has not been specified.
# 2021-11-08 08:14:28.664 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:14:30.639 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/documents/list)
# 2021-11-08 08:14:31.659 | SUCCESS  | relevanceai.transport:make_http_request:63 - Response success! (https://api-aueast.relevance.ai/v1/datasets/ecommerce-6/schema)
# /home/charlene/code/vecdb/.venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
# <div>                            <div id="2b51583d-5217-4d19-b886-ea07a23846f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b51583d-5217-4d19-b886-ea07a23846f3")) {                    Plotly.newPlot(                        "2b51583d-5217-4d19-b886-ea07a23846f3",                        [{"customdata":[["\u6770\u745e\u7684 Jppb11591 S \u5ba0\u7269\u5e8a","Furniture "],["\u57c3\u8482\u6728\u9879\u94fe","Jewellery "],["Silly People Women's Solid Casual Shirt","Clothing "],["\u4f0a\u677e\u662fV01","Computers "],["Karatcraft Crisanta Yellow Gold Diamond 18 K Ring","Jewellery "],["\u6c83\u4f0a\u62c9\u4eba\u5de5\u7ecf\u5178\u7eaf\u6c34\u6676\u9ec4\u91d1\u9540\u5408\u91d1\u9879\u94fe","Jewellery "],["Floozy Its My Choice Women's Push-up Bra","Clothing "],["\u8fc8\u6069\u7279\u56fa\u4f53\u5973\u5b50\u81ea\u884c\u8f66\u77ed\u88e4\uff0c\u5065\u8eab\u77ed\u88e4\uff0c\u6e38\u6cf3\u77ed\u88e4","Clothing "],["Harp Limone Metal Necklace","Jewellery "],["XEBAC XEBAC-CHARGER-B895 Battery Charger","Mobiles & Accessories "],["\u91ce\u9a6c\u8170\u888b","Sports & Fitness "],["U United Mad Angle DU 14 L Backpack","Bags, Wallets & Belts "],["Indian Charm Beads Bone, Stone Necklace","Jewellery "],["Allure Auto CM 367 Car Mat Maruti Ritz","Automotive "],["\u5ba0\u7269\u96e8\u8863\u72d7\uff0c\u732b","Pet Supplies "],["\u963f\u8fbe\u5b9d\u77f3\u5408\u91d1\u5b9d\u77f3\u5957\u88c5","Jewellery "],["My Design Alloy 8K Yellow Gold Bangle Set","Jewellery "],["HomeeHub Polyester Multicolor Self Design Eyelet Window Curtain","Home Furnishing "],["\u514b\u9c81\u514b\u65af-\u730e\u4eba\u5370\u82b1\u7537\u5b69\u7684\u5706\u9888\u7070\u8272T\u6064","Clothing "],["\u8bf1\u60d1\u6c7d\u8f66CM 782 \u6c7d\u8f66\u9a6c\u7279\u9a6c\u9c81\u8482\u5df4\u83b1\u8bfa","Automotive "],["Proganix Agave Nectar Plus Silica Curling Cream Plus Defrizzant Hair Styler","Beauty and Personal Care "],["\u5c3c\u96f7\u83ab\u9762\u5305\u673a","Footwear "],["\u9e3d\u5b50\u7279\u91cc\u666e\u5229\u5361\u8fbe\u4f0a 2 L","Kitchen & Dining "],["NAVISHA Plastic Hand Juicer","Kitchen & Dining "],["Joy Living Garden Plant Container Set","Tools & Hardware "],["Laviva Elegant Looking Floral Design Beads Rakhi Design Designer Rakhi","Home Decor & Festive Needs "],["Shaftesbury London Men's Solid Formal Shirt","Clothing "],["American Club ExclusiveTrolleyBag11KH Expandable  Check-in Luggage - 24","Bags, Wallets & Belts "],["\u5947\u62c9\u683c\u8d1d\u5229\u65f6\u5c1a\u548c\u65f6\u5c1a\u7684\u8d1d\u5229\u65af","Footwear "],["Hako HP Compaq Presario CQ45-207TU 6 Cell Laptop Battery","Computers "],["\u82f9\u679c iPad \u8ff7\u4f60/\u89c6\u7f51\u819c\u663e\u793a\u7684\u6bcf\u65e5\u5bf9\u8c61\u540e\u76d6","Mobiles & Accessories "],["Myesquire Brown Aroma Burner Combo Lemongrass Liquid Air Freshener","Home Decor & Festive Needs "],["Sukkhi Copper Yellow Gold Bangle Set","Jewellery "],["Ladyland Cozy Women's Full Coverage Bra","Clothing "],["\u8bf1\u60d1\u6c7d\u8f66CM 1164 \u6c7d\u8f66\u57ab HM \u5927\u4f7f 2.0D","Automotive "],["\u8482\u5a05\u7531\u5341\u5bf9\u5341\u65f6\u5c1a\u5973\u5b50\u4fef\u5367\u6491\u80f8\u7f69","Clothing "],["diva boutique Regular Fit Women's Red Trousers","Clothing "],["\u5185\u8054\u661f\u73af\u5145\u6c14\u6c34\u6e38\u620f","Baby Care "],["\u4f0a\u59c6\u5229\u8857\u5408\u91d1\u9879\u94fe","Jewellery "],["MINDITDADDY Loafers","Footwear "],["\u624e\u5361\u5b9d\u77f3\u65af\u7279\u6797\u94f6\u9540\u77f3\u9879\u94fe","Jewellery "],["Simrit Women's Nighty","Clothing "],["\u6c83\u62c9\u5229\u74e6\u91d1\u5c5e\u5de7\u514b\u529b","Jewellery "],["BlueStone Yellow Gold Diamond, Amethyst 18 Bracelet","Jewellery "],["\u7d22\u74e6\u59c6\u56fd\u9645\u5b54\u96c0\u4e0e\u7c73\u5a1c\u827a\u672f\u5c55 - 4 \u5398\u7c73","Home Decor & Festive Needs "],["Xupply Square Pack  ...
